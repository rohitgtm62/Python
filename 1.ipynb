# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from brokenaxes import brokenaxes
from matplotlib.figure import Figure

# %%
data = pd.read_excel("E:\EHF_ERA5\Line plots/monthly_decadal.xlsx", sheet_name = "Sheet1")
data.head(7)
# Out:
#   Month  1981_1990  1991_2000  2001-2010  2011-2020
# 0   JAN     10.034     9.8114     10.472     10.007
# 1   FEB     12.124    12.1490     12.848     12.932
# 2   MAR     15.833    16.1940     16.512     16.300
# 3   APR     18.879    19.2060     19.508     19.271
# 4   MAY     20.911    21.1140     21.011     21.289
# 5   JUN     21.966    22.0540     22.078     22.592
# 6   JUL     21.680    21.9870     22.158     22.371

# %%
plt.figure(figsize=(25,15), dpi=300)
plt.plot(data['Month'], data['2011-2020'],label='2011-2020',color = 'red')
plt.plot(data['Month'], data['2001-2010'],label='2001-2010',color = 'orange')
plt.plot(data['Month'], data['1991_2000'],label='1991-2000',color = 'blue')
plt.plot(data['Month'], data['1981_1990'],label='1981-1990',color = 'violet')



csfont = {'fontname':'Times New Roman','fontsize': 44}
#plt.xlabel('Year',**csfont)
plt.ylabel('Mean Temperature ($^\circ$C)',**csfont)
#plt.title('JAN', **csfont)
#plt.ylim((-10,35))
#plt.legend(ncol=1,frameon=True,loc='upper left',fontsize=25, shadow=True)
plt.legend(prop={'weight': 'bold', 'size': 25, 'family': 'serif'}, shadow=True,facecolor='lightgray');
plt.grid()

plt.rc('xtick',labelsize=30)
plt.rc('ytick',labelsize=30)

plt.savefig('E:\EHF_ERA5\Line plots\monthly_decadal.png', dpi=300)
