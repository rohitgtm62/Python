# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Out:
#    Year  DTR_JAN  DTR_FEB  DTR_MAR  DTR_APR  DTR_MAY   DTR_JUN   DTR_JUL  \
# 0  1979   41.864   46.480   48.436   44.314  39.5156  33.64790  29.76827
# 1  1980   46.080   45.139   48.111   47.000  38.7514  30.38059  27.96860
# 2  1981   45.227   44.439   45.396   41.107  37.5318  32.88883  27.98440
# 3  1982   43.206   48.115   48.029   44.301  41.3087  31.68303  29.74960
# 4  1983   44.566   46.746   45.545   45.322  40.0661  35.97840  30.19240
#
#    DTR_AUG   DTR_SEP  DTR_OCT  DTR_NOV  DTR_DEC
# 0  29.0279  31.04810  37.6956   40.746   45.197
# 1  28.4695  29.23312  36.2953   44.187   42.128
# 2  27.3657  30.21490  36.6636   43.655   45.258
# 3  28.1610  30.77560  36.8166   42.745   42.886
# 4  28.3833  29.73671  38.2220   42.730   43.783

# %%
plt.plot(data['Year'], data['DTR_JAN'], label='DTR_JAN')
plt.plot(data['Year'], data['DTR_FEB'], label='DTR_FEB')
plt.plot(data['Year'], data['DTR_MAR'], label='DTR_MAR')
plt.plot(data['Year'], data['DTR_APR'], label='DTR_APR')
plt.plot(data['Year'], data['DTR_MAY'], label='DTR_MAY')
plt.plot(data['Year'], data['DTR_JUN'], label='DTR_JUN')
plt.plot(data['Year'], data['DTR_JUL'], label='DTR_JUL')
plt.plot(data['Year'], data['DTR_AUG'], label='DTR_AUG')
plt.plot(data['Year'], data['DTR_SEP'], label='DTR_SEP')
plt.plot(data['Year'], data['DTR_OCT'], label='DTR_OCT')
plt.plot(data['Year'], data['DTR_NOV'], label='DTR_NOV')
plt.plot(data['Year'], data['DTR_DEC'], label='DTR_DEC')
plt.legend ()

# %%
data = pd.read_excel("E:\DTR_EHF_ERA5\yearmean_DTR_EHF\yearmean.xlsx", sheet_name = "Sheet1")
data.head()
# Out:
#    Year  Minimum    Mean  Maximum  DTR_yearmean
# 0  1979  -8.2742  17.572   28.264       36.5382
# 1  1980  -8.5278  17.424   28.044       36.5718
# 2  1981  -8.7436  17.253   27.690       36.4336
# 3  1982  -9.4020  17.152   27.681       37.0830
# 4  1983  -9.2244  17.014   27.596       36.8204

# %%
plt.plot(data['Year'], data['DTR_yearmean'], label='DTR')
plt.legend(loc='best')

# %%
plt.plot(data['Year'], data['DTR_yearmean'], label='DTR')
plt.plot(data['Year'], data['Minimum'], label='Min')
plt.plot(data['Year'], data['Maximum'], label='Max')
plt.legend(loc='best')
