# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from brokenaxes import brokenaxes
from matplotlib.figure import Figure

# %%
data = pd.read_excel("jan_all.xlsx", sheet_name = "Sheet1")
data.head(7)
# Out:
#      Year   THM_JAN   TWN_JAN    SHN_JAN    AZL_JAN    IPH_JAN    BNK_JAN  \
# 0  1979.0 -2.057786 -2.792761  11.195987  14.979838  13.162379  17.571020
# 1  1980.0 -3.273462 -6.448265  10.387151  14.399850  12.571493  17.562544
# 2  1981.0 -5.197474 -6.347765  10.749189  14.839382  12.802762  17.699368
# 3  1982.0 -1.905221 -2.451306  11.802614  15.128771  13.709676  18.028715
# 4  1983.0 -5.766566 -8.420711   9.666705  14.069293  11.875264  15.860114
# 5  1984.0 -3.796541 -5.966353  10.062648  14.124990  11.974552  16.409832
# 6  1985.0 -3.688777 -4.834225  11.118494  15.014953  13.134530  17.868885
#
#      DBR_JAN    GHY_JAN    DHB_JAN  ...   TWN_DEC    SHN_DEC    AZL_DEC  \
# 0  16.075642  16.805775  18.278147  ... -4.185490  12.023046  15.719708
# 1  16.121655  16.799721  17.478996  ...  0.013643  12.886630  15.838496
# 2  17.012827  16.974079  17.825294  ... -3.287458  12.133518  16.147343
# 3  18.203075  17.894312  18.700727  ... -2.510588  11.302007  14.367908
# ...

# %%
plt.plot('Year','Mean',data=data, color = 'red', label='Black Carbon')	# plot ('xlabel','ylabel',data=obj)
plt.xlabel('Year')
plt.ylabel('BC Surface Mass Conc. (units)')
plt.title('EHF')
plt.legend()

# %%
plt.figure(figsize=(20,15), dpi=300)
#plt.suptitle('2meter-Temperature at 11 locations of EH foothills', fontdict={'fontname': 'Sans', 'fontsize': 40})

plt.subplot(4,3,1)
plt.plot(data['Year'], data['DAC_JAN'],label='DAC')
plt.plot(data['Year'], data['AGA_JAN'],label='AGA')
plt.plot(data['Year'], data['DHB_JAN'],label='DHB')
plt.plot(data['Year'], data['BNK_JAN'],label='BNK')
plt.plot(data['Year'], data['GHY_JAN'],label='GHY')
plt.plot(data['Year'], data['DBR_JAN'],label='DBR')
plt.plot(data['Year'], data['AZL_JAN'],label='AZL')
plt.plot(data['Year'], data['IPH_JAN'],label='IPH')
plt.plot(data['Year'], data['SHN_JAN'],label='SHN')
plt.plot(data['Year'], data['THM_JAN'],label='THM')	
plt.plot(data['Year'], data['TWN_JAN'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('JAN', **csfont)
plt.ylim((-10,35))
plt.legend(ncol=6,frameon=False,loc='upper right')
plt.grid()
#plt.savefig('jan.png', dpi=300)
plt.subplot(4,3,2)
plt.plot(data['Year'], data['DAC_FEB'],label='DAC')
plt.plot(data['Year'], data['AGA_FEB'],label='AGA')
plt.plot(data['Year'], data['DHB_FEB'],label='DHB')
plt.plot(data['Year'], data['BNK_FEB'],label='BNK')
plt.plot(data['Year'], data['GHY_FEB'],label='GHY')
plt.plot(data['Year'], data['DBR_FEB'],label='DBR')
plt.plot(data['Year'], data['AZL_FEB'],label='AZL')
plt.plot(data['Year'], data['IPH_FEB'],label='IPH')
plt.plot(data['Year'], data['SHN_FEB'],label='SHN')
plt.plot(data['Year'], data['THM_FEB'],label='THM')	
plt.plot(data['Year'], data['TWN_FEB'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('FEB', **csfont)
plt.legend(ncol=5,frameon=False,bbox_to_anchor=(0.5, 1.4), loc='upper center')
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,3)
plt.plot(data['Year'], data['DAC_MAR'],label='DAC')
plt.plot(data['Year'], data['AGA_MAR'],label='AGA')
plt.plot(data['Year'], data['DHB_MAR'],label='DHB')
plt.plot(data['Year'], data['BNK_MAR'],label='BNK')
plt.plot(data['Year'], data['GHY_MAR'],label='GHY')
plt.plot(data['Year'], data['DBR_MAR'],label='DBR')
plt.plot(data['Year'], data['AZL_MAR'],label='AZL')
plt.plot(data['Year'], data['IPH_MAR'],label='IPH')
plt.plot(data['Year'], data['SHN_MAR'],label='SHN')
plt.plot(data['Year'], data['THM_MAR'],label='THM')	
plt.plot(data['Year'], data['TWN_MAR'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('MAR', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,4)
plt.plot(data['Year'], data['DAC_APR'],label='DAC')
plt.plot(data['Year'], data['AGA_APR'],label='AGA')
plt.plot(data['Year'], data['DHB_APR'],label='DHB')
plt.plot(data['Year'], data['BNK_APR'],label='BNK')
plt.plot(data['Year'], data['GHY_APR'],label='GHY')
plt.plot(data['Year'], data['DBR_APR'],label='DBR')
plt.plot(data['Year'], data['AZL_APR'],label='AZL')
plt.plot(data['Year'], data['IPH_APR'],label='IPH')
plt.plot(data['Year'], data['SHN_APR'],label='SHN')
plt.plot(data['Year'], data['THM_APR'],label='THM')	
plt.plot(data['Year'], data['TWN_APR'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('APR', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,5)
plt.plot(data['Year'], data['DAC_MAY'],label='DAC')
plt.plot(data['Year'], data['AGA_MAY'],label='AGA')
plt.plot(data['Year'], data['DHB_MAY'],label='DHB')
plt.plot(data['Year'], data['BNK_MAY'],label='BNK')
plt.plot(data['Year'], data['GHY_MAY'],label='GHY')
plt.plot(data['Year'], data['DBR_MAY'],label='DBR')
plt.plot(data['Year'], data['AZL_MAY'],label='AZL')
plt.plot(data['Year'], data['IPH_MAY'],label='IPH')
plt.plot(data['Year'], data['SHN_MAY'],label='SHN')
plt.plot(data['Year'], data['THM_MAY'],label='THM')	
plt.plot(data['Year'], data['TWN_MAY'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('MAY', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,6)
plt.plot(data['Year'], data['DAC_JUN'],label='DAC')
plt.plot(data['Year'], data['AGA_JUN'],label='AGA')
plt.plot(data['Year'], data['DHB_JUN'],label='DHB')
plt.plot(data['Year'], data['BNK_JUN'],label='BNK')
plt.plot(data['Year'], data['GHY_JUN'],label='GHY')
plt.plot(data['Year'], data['DBR_JUN'],label='DBR')
plt.plot(data['Year'], data['AZL_JUN'],label='AZL')
plt.plot(data['Year'], data['IPH_JUN'],label='IPH')
plt.plot(data['Year'], data['SHN_JUN'],label='SHN')
plt.plot(data['Year'], data['THM_JUN'],label='THM')	
plt.plot(data['Year'], data['TWN_JUN'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('JUN', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,7)
plt.plot(data['Year'], data['DAC_JUL'],label='DAC')
plt.plot(data['Year'], data['AGA_JUL'],label='AGA')
plt.plot(data['Year'], data['DHB_JUL'],label='DHB')
plt.plot(data['Year'], data['BNK_JUL'],label='BNK')
plt.plot(data['Year'], data['GHY_JUL'],label='GHY')
plt.plot(data['Year'], data['DBR_JUL'],label='DBR')
plt.plot(data['Year'], data['AZL_JUL'],label='AZL')
plt.plot(data['Year'], data['IPH_JUL'],label='IPH')
plt.plot(data['Year'], data['SHN_JUL'],label='SHN')
plt.plot(data['Year'], data['THM_JUL'],label='THM')	
plt.plot(data['Year'], data['TWN_JUL'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('JUL', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,8)
plt.plot(data['Year'], data['DAC_AUG'],label='DAC')
plt.plot(data['Year'], data['AGA_AUG'],label='AGA')
plt.plot(data['Year'], data['DHB_AUG'],label='DHB')
plt.plot(data['Year'], data['BNK_AUG'],label='BNK')
plt.plot(data['Year'], data['GHY_AUG'],label='GHY')
plt.plot(data['Year'], data['DBR_AUG'],label='DBR')
plt.plot(data['Year'], data['AZL_AUG'],label='AZL')
plt.plot(data['Year'], data['IPH_AUG'],label='IPH')
plt.plot(data['Year'], data['SHN_AUG'],label='SHN')
plt.plot(data['Year'], data['THM_AUG'],label='THM')	
plt.plot(data['Year'], data['TWN_AUG'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('AUG', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,9)
plt.plot(data['Year'], data['DAC_SEP'],label='DAC')
plt.plot(data['Year'], data['AGA_SEP'],label='AGA')
plt.plot(data['Year'], data['DHB_SEP'],label='DHB')
plt.plot(data['Year'], data['BNK_SEP'],label='BNK')
plt.plot(data['Year'], data['GHY_SEP'],label='GHY')
plt.plot(data['Year'], data['DBR_SEP'],label='DBR')
plt.plot(data['Year'], data['AZL_SEP'],label='AZL')
plt.plot(data['Year'], data['IPH_SEP'],label='IPH')
plt.plot(data['Year'], data['SHN_SEP'],label='SHN')
plt.plot(data['Year'], data['THM_SEP'],label='THM')	
plt.plot(data['Year'], data['TWN_SEP'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
#plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('SEP', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,10)
plt.plot(data['Year'], data['DAC_OCT'],label='DAC')
plt.plot(data['Year'], data['AGA_OCT'],label='AGA')
plt.plot(data['Year'], data['DHB_OCT'],label='DHB')
plt.plot(data['Year'], data['BNK_OCT'],label='BNK')
plt.plot(data['Year'], data['GHY_OCT'],label='GHY')
plt.plot(data['Year'], data['DBR_OCT'],label='DBR')
plt.plot(data['Year'], data['AZL_OCT'],label='AZL')
plt.plot(data['Year'], data['IPH_OCT'],label='IPH')
plt.plot(data['Year'], data['SHN_OCT'],label='SHN')
plt.plot(data['Year'], data['THM_OCT'],label='THM')	
plt.plot(data['Year'], data['TWN_OCT'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
plt.xlabel('Year',**csfont)
plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('OCT', **csfont)
#plt.legend(ncol=4,frameon=False)
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,11)
plt.plot(data['Year'], data['DAC_NOV'],label='DAC')
plt.plot(data['Year'], data['AGA_NOV'],label='AGA')
plt.plot(data['Year'], data['DHB_NOV'],label='DHB')
plt.plot(data['Year'], data['BNK_NOV'],label='BNK')
plt.plot(data['Year'], data['GHY_NOV'],label='GHY')
plt.plot(data['Year'], data['DBR_NOV'],label='DBR')
plt.plot(data['Year'], data['AZL_NOV'],label='AZL')
plt.plot(data['Year'], data['IPH_NOV'],label='IPH')
plt.plot(data['Year'], data['SHN_NOV'],label='SHN')
plt.plot(data['Year'], data['THM_NOV'],label='THM')	
plt.plot(data['Year'], data['TWN_NOV'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('NOV', **csfont)
#plt.legend(ncol=4,frameon=False, loc='lower right')
plt.ylim((-10,35))
plt.grid()

plt.subplot(4,3,12)
plt.plot(data['Year'], data['DAC_DEC'],label='DAC')
plt.plot(data['Year'], data['AGA_DEC'],label='AGA')
plt.plot(data['Year'], data['DHB_DEC'],label='DHB')
plt.plot(data['Year'], data['BNK_DEC'],label='BNK')
plt.plot(data['Year'], data['GHY_DEC'],label='GHY')
plt.plot(data['Year'], data['DBR_DEC'],label='DBR')
plt.plot(data['Year'], data['AZL_DEC'],label='AZL')
plt.plot(data['Year'], data['IPH_DEC'],label='IPH')
plt.plot(data['Year'], data['SHN_DEC'],label='SHN')
plt.plot(data['Year'], data['THM_DEC'],label='THM')	
plt.plot(data['Year'], data['TWN_DEC'],label='TWN')
csfont = {'fontname':'Times New Roman','fontsize': 24}
plt.xlabel('Year',**csfont)
#plt.ylabel('Temperature ($^\circ$C)',**csfont)
plt.title('DEC', **csfont)
#plt.legend(ncol=1,frameon=False,bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylim((-10,35))
plt.grid()


plt.tight_layout()
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

plt.savefig('panel_loc_grid_uniform_legend.png', dpi=300)

# %%
plt.plot(data['Year'], data['JAN'],'b--o', linewidth=2, markersize=10)

# %%
plt.plot(data['Year'], data['JAN'], color='green', marker='o', linestyle='dashed', linewidth=2, markersize=10)
